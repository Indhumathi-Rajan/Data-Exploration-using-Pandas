# %% [markdown]
# # DATA EXPLORATION USING PANDAS

# %% [markdown]
# ## List of Top 50 Largest Companies in India

# %% [markdown]
# ####
# This Dataset lists the Top 50 largest companies in India in terms of their revenue, net profit and total assets, according to the American business magazines Fortune and Forbes.
#
# 2022 Forbes List
#
# This list is based on the Forbes Global 2000, which ranks the world's 2,000 largest publicly traded companies. The Forbes list takes into account a multitude of factors, including the revenue, net profit, total assets and market value of each company; each factor is given a weighted rank in terms of importance when considering the overall ranking. The table below also lists the headquarters location and industry sector of each company. The figures are in billions of US dollars and are for the year 2022. All 50 companies from India in the Forbes 2000 are listed.

# %%
import pandas as pd

# %% [markdown]
# #### pandas library imported as pd for data exploration

# %%
sample=pd.read_csv("C://Users//indhu//OneDrive//Desktop//PYTHON WORKINGS//List of largest companies in India.csv")

# %% [markdown]
# #### List of largest companies in India.csv dataset is read from the location

# %%
sample
# Out:
#     Unnamed: 0  Rank  Forbes 2000 rank                                Name  \
# 0            0     1                54                 Reliance Industries
# 1            1     2               105                 State Bank of India
# 2            2     3               154                           HDFC Bank
# 3            3     4               205                          ICICI Bank
# 4            4     5               229     Oil and Natural Gas Corporation
# 5            5     6               269                                HDFC
# 6            6     7               358              Indian Oil Corporation
# 7            7     8               385           Tata Consultancy Services
# 8            8     9               408                          Tata Steel
# 9            9    10               432                           Axis Bank
# 10          10    11               484                        NTPC Limited
# ...

# %% [markdown]
# #### This dataset is downloaded from kaggle.com

# %%
sample.head()
# Out:
#    Unnamed: 0  Rank  Forbes 2000 rank                             Name  \
# 0           0     1                54              Reliance Industries
# 1           1     2               105              State Bank of India
# 2           2     3               154                        HDFC Bank
# 3           3     4               205                       ICICI Bank
# 4           4     5               229  Oil and Natural Gas Corporation
#
#   Headquarters  Revenue(billions US$)  Profit(billions US$)  \
# 0       Mumbai                  86.85                  7.81
# 1       Mumbai                  54.52                  4.32
# 2       Mumbai                  22.51                  5.11
# 3       Mumbai                  21.89                  3.01
# 4    New Delhi                  66.28                  6.00
#
#    Assets(billions US$)  Value(billions US$)      Industry
# 0                192.59               228.63  Conglomerate
# ...

# %% [markdown]
# #### The head function shows first 5 observations of the dataset

# %%
sample.tail()
# Out:
#     Unnamed: 0  Rank  Forbes 2000 rank                Name Headquarters  \
# 45          45    46              1705  Adani Transmission    Ahmedabad
# 46          46    47              1730       Tech Mahindra         Pune
# 47          47    48              1746     Adani Total Gas    Ahmedabad
# 48          48    49              1756          Bajaj Auto         Pune
# 49          49    50              1759               DMart       Mumbai
#
#     Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 45                   1.49                  0.16                  6.11
# 46                   5.72                  0.69                  5.51
# 47                   0.35                  0.07                  0.50
# 48                   4.54                  0.83                  4.51
# 49                   4.00                  0.20                  1.93
#
#     Value(billions US$)     Industry
# 45                38.15    Utilities
# ...

# %% [markdown]
# #### The tail function shows last 5 observations of the dataset

# %%
sample.count()
# Out:
# Unnamed: 0               50
# Rank                     50
# Forbes 2000 rank         50
# Name                     50
# Headquarters             50
# Revenue(billions US$)    50
# Profit(billions US$)     50
# Assets(billions US$)     50
# Value(billions US$)      50
# Industry                 50
# dtype: int64

# %% [markdown]
# #### The count function shows the number of observations in each variable

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             50 non-null     int64
#  1   Rank                   50 non-null     int64
#  2   Forbes 2000 rank       50 non-null     int64
#  3   Name                   50 non-null     object
#  4   Headquarters           50 non-null     object
#  5   Revenue(billions US$)  50 non-null     float64
#  6   Profit(billions US$)   50 non-null     float64
#  7   Assets(billions US$)   50 non-null     float64
#  8   Value(billions US$)    50 non-null     float64
#  9   Industry               50 non-null     object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 4.0+ KB

# %% [markdown]
# #### The info function shows the column names, the non-null count and datatype of variables

# %%
sample.describe()
# Out:
#        Unnamed: 0      Rank  Forbes 2000 rank  Revenue(billions US$)  \
# count    50.00000  50.00000         50.000000              50.000000
# mean     24.50000  25.50000        925.680000              17.383600
# std      14.57738  14.57738        510.938929              18.483696
# min       0.00000   1.00000         54.000000               0.350000
# 25%      12.25000  13.25000        547.750000               6.192500
# 50%      24.50000  25.50000        824.500000              11.500000
# 75%      36.75000  37.75000       1430.250000              20.017500
# max      49.00000  50.00000       1759.000000              86.850000
#
#        Profit(billions US$)  Assets(billions US$)  Value(billions US$)
# count             50.000000             50.000000             50.00000
# mean               1.771720             70.634800             34.13380
# std                1.718154            111.940424             40.86649
# ...

# %% [markdown]
# #### The describe function is used to perform functions like count,mean,standard deviation,minimum value, 25%, 50%,75% and maximum value in each variable

# %%
sample.shape
# Out:
# (50, 10)

# %% [markdown]
# #### The shape function shows the number of observations and number of variables available in the dataset

# %%
sample.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Forbes 2000 rank', 'Name', 'Headquarters',
#        'Revenue(billions US$)', 'Profit(billions US$)', 'Assets(billions US$)',
#        'Value(billions US$)', 'Industry'],
#       dtype='object')

# %% [markdown]
# #### The columns function shows all the variables in the dataset

# %%
sample.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %% [markdown]
# #### The index function shows the starting and ending value of index and number of steps performed between each index

# %%
sample.sort_values(['Revenue(billions US$)'],ascending=True)
# Out:
#     Unnamed: 0  Rank  Forbes 2000 rank                                Name  \
# 47          47    48              1746                     Adani Total Gas
# 42          42    43              1570                  Adani Green Energy
# 45          45    46              1705                  Adani Transmission
# 41          41    42              1489           Adani Ports & SEZ Limited
# 37          37    38              1514  Indian Railway Finance Corporation
# 44          44    45              1687                        Asian Paints
# 49          49    50              1759                               DMart
# 48          48    49              1756                          Bajaj Auto
# 39          39    40              1472                       IndusInd Bank
# 36          36    37              1362                  Sun Pharmaceutical
# 24          24    25               822     Power Grid Corporation of India
# ...

# %% [markdown]
# #### sort_values function helps in sorting the observations in ascending or decending order

# %%
sample['Headquarters'].value_counts()
# Out:
# Mumbai       22
# New Delhi     9
# Ahmedabad     5
# Bangalore     4
# Kolkata       3
# Pune          3
# Noida         1
# Gurgaon       1
# Vadodara      1
# Chennai       1
# Name: Headquarters, dtype: int64

# %% [markdown]
# #### The value_counts function is used to count the number of times value occured under the variable

# %%
sample.drop_duplicates(inplace=True)

# %% [markdown]
# #### The drop_duplicates function is used to remove the duplicate observations from the dataset

# %%
sample_subset=sample[['Name','Headquarters','Industry']]

# %% [markdown]
# #### The subset function is used to select the necessary variables from the dataset

# %%
sample_subset
# Out:
#                                   Name Headquarters            Industry
# 0                  Reliance Industries       Mumbai        Conglomerate
# 1                  State Bank of India       Mumbai             Banking
# 2                            HDFC Bank       Mumbai             Banking
# 3                           ICICI Bank       Mumbai             Banking
# 4      Oil and Natural Gas Corporation    New Delhi         Oil and gas
# 5                                 HDFC       Mumbai          Financials
# 6               Indian Oil Corporation    New Delhi         Oil and gas
# 7            Tata Consultancy Services       Mumbai            Infotech
# 8                           Tata Steel      Kolkata      Iron and steel
# 9                            Axis Bank       Mumbai             Banking
# 10                        NTPC Limited    New Delhi           Utilities
# 11                     Larsen & Toubro       Mumbai       Capital goods
# ...

# %% [markdown]
# #### This dataset is the subset of sample dataset

# %%
sample_row=sample[sample['Profit(billions US$)']>2]

# %% [markdown]
# #### The row function is used to filter the observations based on certain criteria

# %%
sample_row
# Out:
#     Unnamed: 0  Rank  Forbes 2000 rank                             Name  \
# 0            0     1                54              Reliance Industries
# 1            1     2               105              State Bank of India
# 2            2     3               154                        HDFC Bank
# 3            3     4               205                       ICICI Bank
# 4            4     5               229  Oil and Natural Gas Corporation
# 5            5     6               269                             HDFC
# 6            6     7               358           Indian Oil Corporation
# 7            7     8               385        Tata Consultancy Services
# 8            8     9               408                       Tata Steel
# 10          10    11               484                     NTPC Limited
# 12          12    13               539                          Infosys
# 14          14    15               593                  Vedanta Limited
# ...

# %% [markdown]
# #### This dataset is the filtered dataset using row_subset function

# %%
sample['Expenses']=sample['Revenue(billions US$)']-sample['Profit(billions US$)']

# %% [markdown]
# #### This function is used to create or add a variable in the dataset

# %%
sample
# Out:
#     Unnamed: 0  Rank  Forbes 2000 rank                                Name  \
# 0            0     1                54                 Reliance Industries
# 1            1     2               105                 State Bank of India
# 2            2     3               154                           HDFC Bank
# 3            3     4               205                          ICICI Bank
# 4            4     5               229     Oil and Natural Gas Corporation
# 5            5     6               269                                HDFC
# 6            6     7               358              Indian Oil Corporation
# 7            7     8               385           Tata Consultancy Services
# 8            8     9               408                          Tata Steel
# 9            9    10               432                           Axis Bank
# 10          10    11               484                        NTPC Limited
# ...

# %% [markdown]
# #### The dataset after adding a variable 'Expenses'

# %%
sample_index=sample.set_index("Name")

# %% [markdown]
# #### The set_index function is used to set any variable as index

# %%
sample_index
# Out:
#                                     Unnamed: 0  Rank  Forbes 2000 rank  \
# Name
# Reliance Industries                          0     1                54
# State Bank of India                          1     2               105
# HDFC Bank                                    2     3               154
# ICICI Bank                                   3     4               205
# Oil and Natural Gas Corporation              4     5               229
# HDFC                                         5     6               269
# Indian Oil Corporation                       6     7               358
# Tata Consultancy Services                    7     8               385
# Tata Steel                                   8     9               408
# Axis Bank                                    9    10               432
# NTPC Limited                                10    11               484
# Larsen & Toubro                             11    12               514
# ...

# %% [markdown]
# #### The dataset after setting 'Name' as index

# %%
sample_index=sample_index.reset_index()

# %% [markdown]
# #### The reset_index function is used to remove variable as index in the dataset

# %%
sample_index
# Out:
#                                   Name  Unnamed: 0  Rank  Forbes 2000 rank  \
# 0                  Reliance Industries           0     1                54
# 1                  State Bank of India           1     2               105
# 2                            HDFC Bank           2     3               154
# 3                           ICICI Bank           3     4               205
# 4      Oil and Natural Gas Corporation           4     5               229
# 5                                 HDFC           5     6               269
# 6               Indian Oil Corporation           6     7               358
# 7            Tata Consultancy Services           7     8               385
# 8                           Tata Steel           8     9               408
# 9                            Axis Bank           9    10               432
# 10                        NTPC Limited          10    11               484
# ...

# %% [markdown]
# #### The dataset after removing the variable as an index

# %%
sample_loc=sample.loc[(sample.Expenses>=15)&(sample.Headquarters=='Mumbai')]

# %% [markdown]
# #### The locate 'loc' function helps to get the necessary observations by locating the variables with conditions

# %%
sample_loc
# Out:
#     Unnamed: 0  Rank  Forbes 2000 rank                       Name  \
# 0            0     1                54        Reliance Industries
# 1            1     2               105        State Bank of India
# 2            2     3               154                  HDFC Bank
# 3            3     4               205                 ICICI Bank
# 5            5     6               269                       HDFC
# 7            7     8               385  Tata Consultancy Services
# 11          11    12               514            Larsen & Toubro
# 15          15    16               615           Bharat Petroleum
# 17          17    18               643        Hindalco Industries
# 20          20    21               729                Tata Motors
#
#    Headquarters  Revenue(billions US$)  Profit(billions US$)  \
# 0        Mumbai                  86.85                  7.81
# 1        Mumbai                  54.52                  4.32
# ...

# %% [markdown]
# #### The dataset after performing locate function

# %%
sample_iloc=sample.iloc[0:6,2:5]

# %% [markdown]
# #### The index location 'iloc' function is used to select the specific observations and variables by giving a range

# %%
sample_iloc
# Out:
#    Forbes 2000 rank                             Name Headquarters
# 0                54              Reliance Industries       Mumbai
# 1               105              State Bank of India       Mumbai
# 2               154                        HDFC Bank       Mumbai
# 3               205                       ICICI Bank       Mumbai
# 4               229  Oil and Natural Gas Corporation    New Delhi
# 5               269                             HDFC       Mumbai

# %% [markdown]
# #### The dataset after performing index location function

# %%
sample_agg=sample.groupby("Headquarters")['Assets(billions US$)'].mean()

# %% [markdown]
# #### The groupby function is used to group the observations based on distinct values in the variables

# %%
sample_agg
# Out:
# Headquarters
# Ahmedabad      6.598000
# Bangalore     49.165000
# Chennai       89.960000
# Gurgaon       34.560000
# Kolkata       22.320000
# Mumbai       103.508182
# New Delhi     66.948889
# Noida         11.570000
# Pune          17.186667
# Vadodara     167.760000
# Name: Assets(billions US$), dtype: float64

# %% [markdown]
# #### The dataset after performing groupby function

# %%
sample['Forbes 2000 rank']=sample['Forbes 2000 rank'].astype('object')

# %% [markdown]
# #### The astype function helps to change the datatype of the variables

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             50 non-null     int64
#  1   Rank                   50 non-null     int64
#  2   Forbes 2000 rank       50 non-null     object
#  3   Name                   50 non-null     object
#  4   Headquarters           50 non-null     object
#  5   Revenue(billions US$)  50 non-null     float64
#  6   Profit(billions US$)   50 non-null     float64
#  7   Assets(billions US$)   50 non-null     float64
#  8   Value(billions US$)    50 non-null     float64
#  9   Industry               50 non-null     object
#  10  Expenses               50 non-null     float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 4.7+ KB

# %% [markdown]
# #### The datatype of 'Forbes 2000 rank' is changed from Integer to Object
